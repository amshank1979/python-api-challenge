# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0            curup  -3.4667  102.5333     18.90        98
# 1        1  stjordalshalsen  63.4681   10.9262     15.47        94
# 2        2           aitape  -3.1374  142.3475     25.34        87
# 3        3        grytviken -54.2811  -36.5092     -3.33        81
# 4        4      vilyuchinsk  52.9306  158.4028     20.15        70
#
#    Cloudiness  Wind Speed Country       Date
# 0          22        0.42      ID  2023-7-25
# 1          40        1.03      NO  2023-7-25
# 2         100        2.58      PG  2023-7-25
# 3          80        4.74      GS  2023-7-25
# 4          45        0.51      RU  2023-7-25

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Load the CSV file with weather and coordinates data into a DataFrame
city_data_df = pd.read_csv('output_data/cities.csv')

# Create a scatter plot with latitude and longitude as x and y, and humidity as the size
map_plot = city_data_df.hvplot.scatter(x='Lng', y='Lat', c='blue', size='Humidity', alpha=0.7, hover_cols=['City', 'Humidity'])

# Show the map
map_plot
# Out:
# :Scatter   [Lng]   (Lat,Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
df = city_data_df[(city_data_df["Max Temp"] > 25) & (city_data_df["Humidity"] > 50) & (city_data_df["Cloudiness"] < 30)]

# Drop any rows with null values
# this seems redundant - wasn't this done when we skipped cities early in WeatherPy?
# yeah, i keep checking - no NaN in "output_data/cities.csv"
df = df.dropna(how="any")

# Display sample data
df.head()
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 35       35  pacific grove  36.6177 -121.9166     30.30        78           0
# 39       39          yanbu  24.0891   38.0637     32.02        58           0
# 42       42        eastham  41.8301  -69.9739     26.08        80           1
# 43       43       galliano  29.4422  -90.2992     33.00        52           0
# 51       51     el granada  37.5027 -122.4694     34.95        68           0
#
#     Wind Speed Country       Date
# 35        3.09      US  2023-7-25
# 39        2.06      SA  2023-7-25
# 42        0.45      US  2023-7-25
# 43        2.06      US  2023-7-25
# 51        9.26      US  2023-7-25

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                         City Country      Lat       Lng  Humidity Hotel Name
# 35             pacific grove      US  36.6177 -121.9166        78
# 39                     yanbu      SA  24.0891   38.0637        58
# 42                   eastham      US  41.8301  -69.9739        80
# 43                  galliano      US  29.4422  -90.2992        52
# 51                el granada      US  37.5027 -122.4694        68
# 52         wailua homesteads      US  22.0669 -159.3780        73
# 56                  kingston      JM  17.9970  -76.7936        73
# 66                     lihue      US  21.9789 -159.3672        65
# 71              port clinton      US  41.5120  -82.9377        68
# 75                    lompoc      US  34.6391 -120.4579        56
# 94                 jamestown      US  42.0970  -79.2353        73
# 111              sakaiminato      JP  35.5500  133.2333        94
# 113            haiku-pauwela      US  20.9219 -156.3051        65
# 114                fortaleza      BR  -3.7227  -38.5247        78
# 134                hachinohe      JP  40.5000  141.5000        67
# 135                   uturoa      PF -16.7333 -151.4333        80
# 139                   kapa'a      US  22.0752 -159.3190        73
# 162               georgetown      MY   5.4112  100.3354        89
# 166            atafu village      TK  -8.5421 -172.5159        72
# 169                   jining      CN  35.4050  116.5814        79
# 171                 afaahiti      PF -17.7500 -149.2833        81
# 182                    papao      PF -17.7500 -149.5500        84
# 199                   miyako      JP  39.6367  141.9525        67
# 200                 hamilton      US  39.1834  -84.5333        55
# 215              porto velho      BR  -8.7619  -63.9039        58
# 219              chillicothe      US  39.3331  -82.9824        61
# 223         lauro de freitas      BR -12.8944  -38.3272        78
# 262                marinette      US  45.1000  -87.6307        73
# 278      fale old settlement      TK  -9.3852 -171.2468        76
# 283                  ha tinh      VN  18.3333  105.9000        87
# 284               fort bragg      US  35.1390  -79.0060        51
# 292  puerto baquerizo moreno      EC  -0.9000  -89.6000        78
# 299                 fukuecho      JP  32.6881  128.8419        85
# 321                 ishigaki      JP  24.3448  124.1572        84
# 333              fredericton      CA  45.9454  -66.6656        78
# 340                 tartouss      SY  34.8890   35.8866        71
# 344                 altamira      BR  -3.2033  -52.2064        89
# 350             cole harbour      CA  44.6724  -63.4751        76
# 353            cockburn town      TC  21.4612  -71.1419        80
# 380                 santanyi      ES  39.3546    3.1291        76
# 382                     gasa      PS  31.5000   34.4667        67
# 398                 manicore      BR  -5.8092  -61.3003        55
# 400                 ibshaway      EG  29.3580   30.6814        52
# 410                  camocim      BR  -2.9022  -40.8411        75
# 432                 seminole      US  28.7086  -81.2081        70
# 442                  abepura      ID  -2.6333  140.5833        78
# 447                    manta      EC  -0.9500  -80.7333        58
# 469              nishifukuma      JP  33.7667  130.4667        78
# 472                   broome      US  42.2506  -75.8330        81
# 476                 zoucheng      CN  35.4006  116.9656        78
# 480                    feijo      BR  -8.1642  -70.3536        53
# 484                    lamar      US  33.6668  -95.5836        54
# 492              bella vista      US  36.4295  -94.2316        54
# 521                    sitia      GR  35.2000   26.0986        56
# 535                kalianget      ID  -7.0500  113.9333        75
# 552                   manado      ID   1.4870  124.8455        69

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey" : geoapify_key,
    "categories" : "accommodation.hotel",
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lng},{lat},{radius}'
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# pacific grove - nearest hotel: Pacific Grove Inn
# yanbu - nearest hotel: No hotel found
# eastham - nearest hotel: Four Points by Sheraton
# galliano - nearest hotel: Fairfield Inn & Suites by Marriott Cut Off-Galliano
# el granada - nearest hotel: Beach House
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# kingston - nearest hotel: Aphrodite Hotel
# lihue - nearest hotel: Kauai Palms
# port clinton - nearest hotel: Island House Hotel
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# jamestown - nearest hotel: DoubleTree Jamestown
# sakaiminato - nearest hotel: かぐら旅館
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# fortaleza - nearest hotel: Hotel Catedral
# hachinohe - nearest hotel: スーパーホテル
# uturoa - nearest hotel: Hawaiki Nui hotel
# kapa'a - nearest hotel: Pono Kai Resort
# georgetown - nearest hotel: Page 63 hostel
# atafu village - nearest hotel: No hotel found
# jining - nearest hotel: No hotel found
# afaahiti - nearest hotel: Omati Lodge
# papao - nearest hotel: Hiti Moana Villa Lodge
# miyako - nearest hotel: ビックウェーブ
# hamilton - nearest hotel: North Vista Manor
# porto velho - nearest hotel: Hotel Slaviero Essential Porto Velho
# chillicothe - nearest hotel: Quality Inn Chillicothe
# lauro de freitas - nearest hotel: Malibu Plaza Hotel
# marinette - nearest hotel: Best Western Riverfront Inn
# fale old settlement - nearest hotel: No hotel found
# ha tinh - nearest hotel: Hong Chau Nha Nhgi
# fort bragg - nearest hotel: Airborne Inn Lodging
# puerto baquerizo moreno - nearest hotel: Dory's House
# fukuecho - nearest hotel: 五島第一ホテル
# ishigaki - nearest hotel: アートホテル石垣島
# fredericton - nearest hotel: Days Inn
# tartouss - nearest hotel: فندق انترادوس
# altamira - nearest hotel: Hotel Vale do Xingu
# cole harbour - nearest hotel: Hearthstone Inn Boutique Hotel Dartmouth/Halifax
# cockburn town - nearest hotel: The Salt Raker Inn
# santanyi - nearest hotel: Santanyí
# gasa - nearest hotel: مسجد الفتح المبين
# manicore - nearest hotel: No hotel found
# ibshaway - nearest hotel: No hotel found
# camocim - nearest hotel: Hotel Camocim
# seminole - nearest hotel: Best Western Plus Sanford
# abepura - nearest hotel: Yoyo
# manta - nearest hotel: La Gaviota
# nishifukuma - nearest hotel: 割烹旅館 正直亭
# broome - nearest hotel: No hotel found
# zoucheng - nearest hotel: No hotel found
# feijo - nearest hotel: Hotel JOAFRAN
# lamar - nearest hotel: 1st St Lofts
# bella vista - nearest hotel: 21c Museum Hotel Bentonville
# sitia - nearest hotel: Itanos Hotel
# kalianget - nearest hotel: No hotel found
# manado - nearest hotel: Swiss Belhotel
#                         City Country      Lat       Lng  Humidity  \
# 35             pacific grove      US  36.6177 -121.9166        78
# 39                     yanbu      SA  24.0891   38.0637        58
# 42                   eastham      US  41.8301  -69.9739        80
# 43                  galliano      US  29.4422  -90.2992        52
# 51                el granada      US  37.5027 -122.4694        68
# 52         wailua homesteads      US  22.0669 -159.3780        73
# 56                  kingston      JM  17.9970  -76.7936        73
# 66                     lihue      US  21.9789 -159.3672        65
# 71              port clinton      US  41.5120  -82.9377        68
# 75                    lompoc      US  34.6391 -120.4579        56
# 94                 jamestown      US  42.0970  -79.2353        73
# 111              sakaiminato      JP  35.5500  133.2333        94
# 113            haiku-pauwela      US  20.9219 -156.3051        65
# 114                fortaleza      BR  -3.7227  -38.5247        78
# 134                hachinohe      JP  40.5000  141.5000        67
# 135                   uturoa      PF -16.7333 -151.4333        80
# 139                   kapa'a      US  22.0752 -159.3190        73
# 162               georgetown      MY   5.4112  100.3354        89
# 166            atafu village      TK  -8.5421 -172.5159        72
# 169                   jining      CN  35.4050  116.5814        79
# 171                 afaahiti      PF -17.7500 -149.2833        81
# 182                    papao      PF -17.7500 -149.5500        84
# 199                   miyako      JP  39.6367  141.9525        67
# 200                 hamilton      US  39.1834  -84.5333        55
# 215              porto velho      BR  -8.7619  -63.9039        58
# 219              chillicothe      US  39.3331  -82.9824        61
# 223         lauro de freitas      BR -12.8944  -38.3272        78
# 262                marinette      US  45.1000  -87.6307        73
# 278      fale old settlement      TK  -9.3852 -171.2468        76
# 283                  ha tinh      VN  18.3333  105.9000        87
# 284               fort bragg      US  35.1390  -79.0060        51
# 292  puerto baquerizo moreno      EC  -0.9000  -89.6000        78
# 299                 fukuecho      JP  32.6881  128.8419        85
# 321                 ishigaki      JP  24.3448  124.1572        84
# 333              fredericton      CA  45.9454  -66.6656        78
# 340                 tartouss      SY  34.8890   35.8866        71
# 344                 altamira      BR  -3.2033  -52.2064        89
# 350             cole harbour      CA  44.6724  -63.4751        76
# 353            cockburn town      TC  21.4612  -71.1419        80
# 380                 santanyi      ES  39.3546    3.1291        76
# 382                     gasa      PS  31.5000   34.4667        67
# 398                 manicore      BR  -5.8092  -61.3003        55
# 400                 ibshaway      EG  29.3580   30.6814        52
# 410                  camocim      BR  -2.9022  -40.8411        75
# 432                 seminole      US  28.7086  -81.2081        70
# 442                  abepura      ID  -2.6333  140.5833        78
# 447                    manta      EC  -0.9500  -80.7333        58
# 469              nishifukuma      JP  33.7667  130.4667        78
# 472                   broome      US  42.2506  -75.8330        81
# 476                 zoucheng      CN  35.4006  116.9656        78
# 480                    feijo      BR  -8.1642  -70.3536        53
# 484                    lamar      US  33.6668  -95.5836        54
# 492              bella vista      US  36.4295  -94.2316        54
# 521                    sitia      GR  35.2000   26.0986        56
# 535                kalianget      ID  -7.0500  113.9333        75
# 552                   manado      ID   1.4870  124.8455        69
#
#                                             Hotel Name
# 35                                   Pacific Grove Inn
# 39                                      No hotel found
# 42                             Four Points by Sheraton
# 43   Fairfield Inn & Suites by Marriott Cut Off-Gal...
# 51                                         Beach House
# 52                  Hilton Garden Inn Kauai Wailua Bay
# 56                                     Aphrodite Hotel
# 66                                         Kauai Palms
# 71                                  Island House Hotel
# 75       Embassy Suites by Hilton Lompoc Central Coast
# 94                                DoubleTree Jamestown
# 111                                              かぐら旅館
# 113                           Inn At Mama's Fish House
# 114                                     Hotel Catedral
# 134                                            スーパーホテル
# 135                                  Hawaiki Nui hotel
# 139                                    Pono Kai Resort
# 162                                     Page 63 hostel
# 166                                     No hotel found
# 169                                     No hotel found
# 171                                        Omati Lodge
# 182                             Hiti Moana Villa Lodge
# 199                                            ビックウェーブ
# 200                                  North Vista Manor
# 215               Hotel Slaviero Essential Porto Velho
# 219                            Quality Inn Chillicothe
# 223                                 Malibu Plaza Hotel
# 262                        Best Western Riverfront Inn
# 278                                     No hotel found
# 283                                 Hong Chau Nha Nhgi
# 284                               Airborne Inn Lodging
# 292                                       Dory's House
# 299                                            五島第一ホテル
# 321                                          アートホテル石垣島
# 333                                           Days Inn
# 340                                      فندق انترادوس
# 344                                Hotel Vale do Xingu
# 350   Hearthstone Inn Boutique Hotel Dartmouth/Halifax
# 353                                 The Salt Raker Inn
# 380                                           Santanyí
# 382                                  مسجد الفتح المبين
# 398                                     No hotel found
# 400                                     No hotel found
# 410                                      Hotel Camocim
# 432                          Best Western Plus Sanford
# 442                                               Yoyo
# 447                                         La Gaviota
# 469                                           割烹旅館 正直亭
# 472                                     No hotel found
# 476                                     No hotel found
# 480                                      Hotel JOAFRAN
# 484                                       1st St Lofts
# 492                       21c Museum Hotel Bentonville
# 521                                       Itanos Hotel
# 535                                     No hotel found
# 552                                     Swiss Belhotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    color="City",
    line_color="black",
    size=80,
    frame_width=800,
    frame_height=600,
    hover_cols=["Hotel Name", "Country", "Humidity"]
)

# Display the map
map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country,Humidity)
